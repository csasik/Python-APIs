# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests, json
import time
import datetime as dt

# %%
# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %%
# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []


# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
#lats = np.random.uniform(low=-90.000, high=90.000, size=10)
#lngs = np.random.uniform(low=-180.000, high=180.000, size=10)
lat_lngs = zip(lats, lngs)

len(lats)
# Out:
# 1500

# %%
weather_frame = pd.DataFrame({'lats':lats,
                           'lngs':lngs})
weather_frame['city']=""
weather_frame.tail()
# Out:
#            lats       lngs city
# 1495 -80.929451  29.470654
# 1496  81.877206  28.095807
# 1497 -80.969460 -82.207777
# 1498 -58.097081  -1.325548
# 1499  80.302654 -83.717217

# %%
# Identify nearest city for each lat, lng combination
cities = []

for index, row in weather_frame.iterrows():
    
    city = citipy.nearest_city(row['lats'], row['lngs']).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
       
    if (len(cities) == 500):
        break
    
    weather_frame.loc[index,'city'] = city
    
# Print the city count to confirm sufficient count
print(f'No of cities - {len(cities)}')
# Out:
# No of cities - 500

# %%
weather_frame2 = weather_frame.loc[weather_frame['city']!= '',:]

# %%
weather_frame = weather_frame2.head(500)
weather_frame.count()
# Out:
# lats    500
# lngs    500
# city    500
# dtype: int64

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"

weather_frame['country'] = ""
weather_frame['ID'] = ""
weather_frame['temperature'] = ""    
weather_frame['humidity'] = ""
weather_frame['cloudiness'] = ""
weather_frame['wind_speed'] = ""
# Out:
# C:\Users\chith\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\chith\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\chith\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# C:\Users\chith\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\chith\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# C:\Users\chith\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
weather_frame = weather_frame.dropna()   
weather_frame.head()
# Out:
#         lats        lngs    city country ID temperature humidity cloudiness  \
# 0  34.099091  126.176157   fukue
# 1  -6.701704  127.074337   ambon
# 2  77.129927  166.884959   pevek
# 3 -68.233555  101.845776  albany
# 4 -54.739801  149.718599  hobart
#
#   wind_speed
# 0
# 1
# 2
# 3
# 4

# %%
for index, row in weather_frame.iterrows():
    
    # Build query URL
    query_url = f"{url}appid={api_key}&q={row['city']}"
    weather_data = requests.get(query_url).json()
    try:
        weather_frame.loc[index,'country'] = weather_data['sys']['country']
        weather_frame.loc[index,'ID'] = weather_data['id']
        weather_frame.loc[index,'temperature'] = weather_data['main']['temp']    
        weather_frame.loc[index,'humidity'] = weather_data['main']['humidity']
        weather_frame.loc[index,'cloudiness'] = weather_data['clouds']['all']
        weather_frame.loc[index,'wind_speed'] = weather_data['wind']['speed']
        print(f"Processing city - {row['city']}, ID number -{weather_data['id']} ") 
        time.sleep(5)
    except(KeyError):
        print('skip city')
# Out:
# Processing city - fukue, ID number -1848373
# Processing city - ambon, ID number -3037899
# Processing city - pevek, ID number -2122090
# Processing city - albany, ID number -5106834
# Processing city - hobart, ID number -2163355
# Processing city - atuona, ID number -4020109
# Processing city - vaini, ID number -1273574
# Processing city - nishihara, ID number -1850144
# Processing city - buala, ID number -2109528
# Processing city - chumikan, ID number -2025256
# Processing city - rikitea, ID number -4030556
# Processing city - klyuchi, ID number -1503153
# Processing city - adrar, ID number -2508813
# skip city
# Processing city - vanimo, ID number -2084442
# Processing city - qaanaaq, ID number -3831208
# skip city
# Processing city - leningradskiy, ID number -2123814
# skip city
# Processing city - hermanus, ID number -3366880
# Processing city - airai, ID number -1651810
# Processing city - djambala, ID number -2260401
# Processing city - busselton, ID number -2075265
# Processing city - sola, ID number -3137942
# Processing city - cidreira, ID number -3466165
# Processing city - cidreira, ID number -3466165
# Processing city - portree, ID number -2640006
# skip city
# Processing city - vestmanna, ID number -2610343
# Processing city - tuktoyaktuk, ID number -6170031
# Processing city - castro, ID number -3896218
# Processing city - cururupu, ID number -3401148
# Processing city - port alfred, ID number -964432
# Processing city - tuktoyaktuk, ID number -6170031
# Processing city - broome, ID number -2656067
# Processing city - castro, ID number -3896218
# Processing city - hermanus, ID number -3366880
# Processing city - marawi, ID number -1701054
# skip city
# Processing city - kieta, ID number -2094027
# Processing city - mago, ID number -2123621
# Processing city - jamestown, ID number -2069194
# Processing city - tiksi, ID number -2015306
# Processing city - bonavista, ID number -5905393
# Processing city - sorland, ID number -3137469
# Processing city - georgetown, ID number -3378644
# Processing city - saskylakh, ID number -2017155
# Processing city - penzance, ID number -2640377
# Processing city - paamiut, ID number -3421193
# Processing city - cape town, ID number -3369157
# Processing city - puerto ayora, ID number -3652764
# skip city
# Processing city - port lincoln, ID number -2063036
# Processing city - namibe, ID number -3347019
# Processing city - busselton, ID number -2075265
# Processing city - saint-augustin, ID number -3031582
# Processing city - kosiv, ID number -704764
# Processing city - pyaozerskiy, ID number -503581
# Processing city - constitucion, ID number -4011743
# Processing city - guilin, ID number -1809498
# Processing city - mataura, ID number -6201424
# Processing city - airai, ID number -1651810
# Processing city - bluff, ID number -2175403
# Processing city - albany, ID number -5106834
# Processing city - samarai, ID number -2132606
# Processing city - leningradskiy, ID number -2123814
# Processing city - bethel, ID number -5880568
# Processing city - ninohe, ID number -2129961
# Processing city - cape town, ID number -3369157
# Processing city - victoria, ID number -1733782
# Processing city - oparino, ID number -515175
# Processing city - goure, ID number -2444219
# Processing city - atar, ID number -2381334
# Processing city - dikson, ID number -1507390
# Processing city - mahebourg, ID number -934322
# Processing city - kanye, ID number -933685
# Processing city - faanui, ID number -4034551
# Processing city - punta arenas, ID number -3874787
# Processing city - albany, ID number -5106834
# Processing city - qaqortoq, ID number -3420846
# Processing city - sitka, ID number -4267710
# Processing city - lingyuan, ID number -2036075
# Processing city - ushuaia, ID number -3833367
# Processing city - cabo san lucas, ID number -3985710
# Processing city - qaanaaq, ID number -3831208
# Processing city - busselton, ID number -2075265
# Processing city - narsaq, ID number -3421719
# Processing city - akdepe, ID number -601551
# Processing city - mahebourg, ID number -934322
# Processing city - punta arenas, ID number -3874787
# Processing city - busselton, ID number -2075265
# Processing city - corinto, ID number -3465512
# Processing city - bluff, ID number -2175403
# Processing city - upernavik, ID number -3418910
# Processing city - albany, ID number -5106834
# skip city
# Processing city - port-gentil, ID number -2396518
# Processing city - atuona, ID number -4020109
# Processing city - praia da vitoria, ID number -3372760
# Processing city - san jose, ID number -1689431
# Processing city - lorengau, ID number -2092164
# skip city
# Processing city - bela vista, ID number -3470177
# Processing city - bacungan, ID number -1729456
# Processing city - iraucuba, ID number -3398028
# Processing city - norman wells, ID number -6089245
# Processing city - rikitea, ID number -4030556
# Processing city - pervomayskoye, ID number -1495256
# Processing city - hermanus, ID number -3366880
# Processing city - dikson, ID number -1507390
# Processing city - saint george, ID number -262462
# Processing city - saint-pierre, ID number -2995603
# skip city
# Processing city - saint-philippe, ID number -6138908
# Processing city - aanekoski, ID number -662095
# Processing city - ushuaia, ID number -3833367
# Processing city - samarai, ID number -2132606
# Processing city - san patricio, ID number -3437029
# Processing city - vaini, ID number -1273574
# Processing city - shache, ID number -1280037
# Processing city - bulaevo, ID number -1525014
# Processing city - busselton, ID number -2075265
# Processing city - new norfolk, ID number -2155415
# Processing city - jacareacanga, ID number -3397763
# Processing city - aranos, ID number -3358666
# Processing city - mahebourg, ID number -934322
# Processing city - matadi, ID number -2313002
# Processing city - atuona, ID number -4020109
# Processing city - cidreira, ID number -3466165
# Processing city - yaan, ID number -2338660
# Processing city - mosquera, ID number -3674292
# Processing city - isla vista, ID number -5359864
# Processing city - khorramshahr, ID number -127319
# Processing city - isangel, ID number -2136825
# Processing city - thames, ID number -2208333
# Processing city - yellowknife, ID number -6185377
# skip city
# Processing city - cranbrook, ID number -5931800
# Processing city - dhidhdhoo, ID number -1337612
# skip city
# Processing city - hualmay, ID number -3939761
# Processing city - lubango, ID number -3347762
# skip city
# Processing city - hermanus, ID number -3366880
# skip city
# Processing city - pa sang, ID number -1151528
# Processing city - auki, ID number -2339937
# Processing city - monchique, ID number -2266268
# Processing city - palu, ID number -1633034
# Processing city - altos, ID number -3407797
# Processing city - port alfred, ID number -964432
# Processing city - phangnga, ID number -1151464
# Processing city - souillac, ID number -3026644
# Processing city - kodiak, ID number -4407665
# Processing city - beloha, ID number -1067565
# Processing city - cape town, ID number -3369157
# Processing city - rikitea, ID number -4030556
# skip city
# Processing city - vallenar, ID number -3868633
# Processing city - saint-philippe, ID number -6138908
# Processing city - faanui, ID number -4034551
# Processing city - port elizabeth, ID number -4501427
# Processing city - rikitea, ID number -4030556
# Processing city - atuona, ID number -4020109
# Processing city - east london, ID number -1006984
# Processing city - challapata, ID number -3921355
# Processing city - torbay, ID number -6167817
# Processing city - touros, ID number -3386213
# Processing city - mataura, ID number -6201424
# Processing city - nikolskoye, ID number -546105
# Processing city - dingle, ID number -1714733
# skip city
# skip city
# Processing city - esperance, ID number -3573739
# Processing city - san patricio, ID number -3437029
# Processing city - koslan, ID number -544084
# Processing city - port-gentil, ID number -2396518
# Processing city - manbij, ID number -167357
# Processing city - aksu, ID number -1524298
# Processing city - leningradskiy, ID number -2123814
# Processing city - upernavik, ID number -3418910
# Processing city - cape town, ID number -3369157
# Processing city - port alfred, ID number -964432
# Processing city - kurilsk, ID number -2123979
# Processing city - minudasht, ID number -132938
# Processing city - broken hill, ID number -2173911
# Processing city - tasiilaq, ID number -3424607
# Processing city - bluff, ID number -2175403
# Processing city - puerto ayora, ID number -3652764
# Processing city - hervey bay, ID number -2146219
# Processing city - okato, ID number -2185763
# Processing city - qaanaaq, ID number -3831208
# Processing city - new norfolk, ID number -2155415
# Processing city - kapaa, ID number -5848280
# Processing city - rikitea, ID number -4030556
# Processing city - namibe, ID number -3347019
# Processing city - port alfred, ID number -964432
# Processing city - pangnirtung, ID number -6096551
# Processing city - pevek, ID number -2122090
# Processing city - torbay, ID number -6167817
# Processing city - punta arenas, ID number -3874787
# Processing city - bredasdorp, ID number -1015776
# Processing city - talnakh, ID number -1490256
# Processing city - namibe, ID number -3347019
# Processing city - rikitea, ID number -4030556
# Processing city - brasilia, ID number -3459342
# Processing city - punta arenas, ID number -3874787
# Processing city - tiksi, ID number -2015306
# Processing city - kodiak, ID number -4407665
# Processing city - turukhansk, ID number -1488903
# Processing city - adeje, ID number -2319133
# skip city
# skip city
# Processing city - albany, ID number -5106834
# Processing city - cienfuegos, ID number -3564124
# Processing city - taoudenni, ID number -2450173
# Processing city - mar del plata, ID number -3863379
# Processing city - avarua, ID number -4035715
# Processing city - busselton, ID number -2075265
# Processing city - san juan del sur, ID number -3616726
# Processing city - popondetta, ID number -2088163
# Processing city - beloha, ID number -1067565
# Processing city - puerto ayora, ID number -3652764
# Processing city - ormara, ID number -1168700
# Processing city - hermanus, ID number -3366880
# Processing city - punta arenas, ID number -3874787
# Processing city - tucuman, ID number -3934608
# Processing city - codrington, ID number -2160063
# Processing city - palaikastron, ID number -256155
# Processing city - busselton, ID number -2075265
# Processing city - yaan, ID number -2338660
# Processing city - palu, ID number -1633034
# Processing city - saint-augustin, ID number -3031582
# Processing city - kodiak, ID number -4407665
# Processing city - pierre, ID number -5767918
# Processing city - ponta do sol, ID number -3453439
# Processing city - tougan, ID number -2354176
# Processing city - kodiak, ID number -4407665
# Processing city - harper, ID number -4696310
# Processing city - ushuaia, ID number -3833367
# Processing city - iqaluit, ID number -5983720
# Processing city - barcelona, ID number -3128760
# Processing city - albany, ID number -5106834
# Processing city - progreso, ID number -3440963
# Processing city - atuona, ID number -4020109
# skip city
# Processing city - rikitea, ID number -4030556
# Processing city - ulety, ID number -2014369
# Processing city - manta, ID number -685981
# Processing city - atuona, ID number -4020109
# Processing city - hamilton, ID number -3573197
# skip city
# Processing city - mataura, ID number -6201424
# Processing city - udachnyy, ID number -2014624
# Processing city - punta arenas, ID number -3874787
# Processing city - lebu, ID number -344979
# Processing city - flinders, ID number -6255012
# Processing city - naze, ID number -2337542
# Processing city - maun, ID number -933366
# Processing city - rikitea, ID number -4030556
# Processing city - ayan, ID number -749747
# Processing city - hilo, ID number -5855927
# Processing city - bethel, ID number -5880568
# Processing city - vaini, ID number -1273574
# Processing city - dikson, ID number -1507390
# Processing city - rozhyshche, ID number -695326
# Processing city - mataura, ID number -6201424
# Processing city - east london, ID number -1006984
# Processing city - busselton, ID number -2075265
# Processing city - kieta, ID number -2094027
# Processing city - new norfolk, ID number -2155415
# Processing city - arraial do cabo, ID number -3471451
# Processing city - geraldton, ID number -5960603
# Processing city - shakawe, ID number -933077
# skip city
# Processing city - kaitangata, ID number -2208248
# Processing city - mataura, ID number -6201424
# skip city
# Processing city - aklavik, ID number -5882953
# skip city
# Processing city - rikitea, ID number -4030556
# Processing city - brae, ID number -2654970
# Processing city - cidreira, ID number -3466165
# skip city
# Processing city - san lazaro, ID number -3581514
# Processing city - puerto colombia, ID number -3671497
# Processing city - longyearbyen, ID number -2729907
# Processing city - yellowknife, ID number -6185377
# Processing city - albany, ID number -5106834
# Processing city - pevek, ID number -2122090
# Processing city - new norfolk, ID number -2155415
# Processing city - darhan, ID number -2031964
# Processing city - rikitea, ID number -4030556
# Processing city - mataura, ID number -6201424
# Processing city - arraial do cabo, ID number -3471451
# Processing city - mataura, ID number -6201424
# Processing city - albany, ID number -5106834
# skip city
# Processing city - port keats, ID number -2063039
# Processing city - sorland, ID number -3137469
# Processing city - ushuaia, ID number -3833367
# Processing city - airai, ID number -1651810
# Processing city - cayenne, ID number -3382160
# Processing city - severo-kurilsk, ID number -2121385
# skip city
# Processing city - broome, ID number -2656067
# Processing city - yumen, ID number -1528998
# skip city
# Processing city - saraza, ID number -1687167
# Processing city - leningradskiy, ID number -2123814
# Processing city - lodja, ID number -211647
# Processing city - oituz, ID number -671896
# skip city
# Processing city - guapi, ID number -3681505
# Processing city - hobart, ID number -2163355
# Processing city - meridian, ID number -4435764
# Processing city - san patricio, ID number -3437029
# Processing city - ushuaia, ID number -3833367
# Processing city - port alfred, ID number -964432
# Processing city - airai, ID number -1651810
# Processing city - ribeira grande, ID number -3372707
# Processing city - bluff, ID number -2175403
# Processing city - castro, ID number -3896218
# Processing city - kaitangata, ID number -2208248
# Processing city - navirai, ID number -3456368
# Processing city - russkaya polyana, ID number -1493423
# Processing city - cape town, ID number -3369157
# Processing city - quatre cocos, ID number -1106643
# skip city
# Processing city - airai, ID number -1651810
# Processing city - hobart, ID number -2163355
# Processing city - punta arenas, ID number -3874787
# Processing city - bredasdorp, ID number -1015776
# Processing city - maniitsoq, ID number -3421982
# Processing city - mataura, ID number -6201424
# Processing city - aswan, ID number -359792
# Processing city - bethel, ID number -5880568
# Processing city - muzhi, ID number -1498161
# Processing city - bereda, ID number -3105522
# Processing city - lagoa, ID number -2267254
# Processing city - tessalit, ID number -2449893
# Processing city - cidreira, ID number -3466165
# Processing city - port elizabeth, ID number -4501427
# Processing city - ilulissat, ID number -3423146
# Processing city - teeli, ID number -1489828
# Processing city - thompson, ID number -6165406
# Processing city - byron bay, ID number -2172880
# Processing city - khatanga, ID number -2022572
# Processing city - castro, ID number -3896218
# skip city
# skip city
# Processing city - ushuaia, ID number -3833367
# skip city
# Processing city - georgetown, ID number -3378644
# Processing city - manaus, ID number -3663517
# Processing city - jamestown, ID number -2069194
# Processing city - mogadishu, ID number -53654
# Processing city - hermanus, ID number -3366880
# skip city
# skip city
# Processing city - port elizabeth, ID number -4501427
# Processing city - tezu, ID number -1254709
# Processing city - talcahuano, ID number -3870282
# skip city
# Processing city - norman wells, ID number -6089245
# Processing city - avarua, ID number -4035715
# Processing city - port elizabeth, ID number -4501427
# Processing city - bluff, ID number -2175403
# skip city
# Processing city - bluff, ID number -2175403
# Processing city - mar del plata, ID number -3863379
# Processing city - kitimat, ID number -5993072
# Processing city - matagami, ID number -2335713
# Processing city - rikitea, ID number -4030556
# Processing city - mataura, ID number -6201424
# Processing city - puerto ayora, ID number -3652764
# Processing city - dauriya, ID number -2025099
# Processing city - severo-kurilsk, ID number -2121385
# Processing city - mataura, ID number -6201424
# Processing city - lebu, ID number -344979
# Processing city - saint-philippe, ID number -6138908
# Processing city - dikson, ID number -1507390
# Processing city - atar, ID number -2381334
# Processing city - nome, ID number -4732862
# Processing city - sisimiut, ID number -3419842
# Processing city - ancud, ID number -3899695
# Processing city - wonthaggi, ID number -2154826
# Processing city - georgetown, ID number -3378644
# skip city
# skip city
# Processing city - rikitea, ID number -4030556
# Processing city - mataura, ID number -6201424
# Processing city - mataura, ID number -6201424
# Processing city - sidney, ID number -5677735
# skip city
# skip city
# Processing city - vaini, ID number -1273574
# Processing city - hithadhoo, ID number -1282256
# Processing city - cabo san lucas, ID number -3985710
# Processing city - esperance, ID number -3573739
# Processing city - dunedin, ID number -2191562
# Processing city - vestmannaeyjar, ID number -3412093
# Processing city - punta arenas, ID number -3874787
# Processing city - klaksvik, ID number -2618795
# Processing city - stephenville, ID number -4734350
# Processing city - komsomolskiy, ID number -1486910
# skip city
# Processing city - bartoszyce, ID number -776337
# Processing city - los llanos de aridane, ID number -2514651
# Processing city - jamestown, ID number -2069194
# Processing city - broome, ID number -2656067
# Processing city - rikitea, ID number -4030556
# Processing city - ushuaia, ID number -3833367
# Processing city - saint-philippe, ID number -6138908
# Processing city - severo-kurilsk, ID number -2121385
# Processing city - ushuaia, ID number -3833367
# Processing city - ambilobe, ID number -1082243
# Processing city - ushuaia, ID number -3833367
# skip city
# Processing city - asyut, ID number -359783
# Processing city - nyzhnya duvanka, ID number -699963
# Processing city - flinders, ID number -6255012
# Processing city - quatre cocos, ID number -1106643
# Processing city - ucluelet, ID number -6171633
# Processing city - aklavik, ID number -5882953
# Processing city - abbeville, ID number -3038789
# Processing city - marzuq, ID number -72181
# Processing city - albany, ID number -5106834
# Processing city - punta arenas, ID number -3874787
# skip city
# Processing city - richards bay, ID number -962367
# Processing city - vaini, ID number -1273574
# Processing city - butaritari, ID number -2110227
# Processing city - sal rei, ID number -3374235
# Processing city - hermanus, ID number -3366880
# Processing city - port elizabeth, ID number -4501427
# skip city
# Processing city - geraldton, ID number -5960603
# Processing city - asyut, ID number -359783
# Processing city - barrow, ID number -3833859
# skip city
# Processing city - albany, ID number -5106834
# Processing city - birigui, ID number -3469989
# Processing city - chokurdakh, ID number -2126123
# Processing city - college, ID number -5859699
# skip city
# Processing city - upernavik, ID number -3418910
# Processing city - puerto ayora, ID number -3652764
# Processing city - rikitea, ID number -4030556
# Processing city - mount isa, ID number -2065594
# Processing city - half moon bay, ID number -5354943
# Processing city - mataura, ID number -6201424
# Processing city - dikson, ID number -1507390
# Processing city - qaanaaq, ID number -3831208
# Processing city - boguchany, ID number -1509844
# Processing city - puerto ayora, ID number -3652764
# Processing city - punta arenas, ID number -3874787
# Processing city - natal, ID number -3394023
# Processing city - kandry, ID number -553169
# skip city
# Processing city - ushuaia, ID number -3833367
# Processing city - port elizabeth, ID number -4501427
# Processing city - tuatapere, ID number -2180815
# Processing city - cape town, ID number -3369157
# Processing city - nikolskoye, ID number -546105
# Processing city - padang, ID number -1633419
# Processing city - hermanus, ID number -3366880
# Processing city - jamestown, ID number -2069194
# Processing city - kapaa, ID number -5848280
# skip city
# Processing city - kapaa, ID number -5848280
# Processing city - saskylakh, ID number -2017155
# Processing city - kokomo, ID number -4922388
# Processing city - irbit, ID number -1505526
# Processing city - carnarvon, ID number -1014034
# Processing city - hami, ID number -1529484
# Processing city - bluff, ID number -2175403
# Processing city - norman wells, ID number -6089245
# Processing city - ushuaia, ID number -3833367
# Processing city - mahebourg, ID number -934322
# Processing city - albany, ID number -5106834
# Processing city - vaini, ID number -1273574
# skip city
# Processing city - pevek, ID number -2122090
# Processing city - kui buri, ID number -1152562
# Processing city - punta arenas, ID number -3874787
# skip city
# Processing city - akcaabat, ID number -752627
# Processing city - kaniama, ID number -214389
# Processing city - mataura, ID number -6201424
# Processing city - rikitea, ID number -4030556
# Processing city - naze, ID number -2337542
# Processing city - albany, ID number -5106834
# skip city
# Processing city - fuldatal, ID number -2923815
# Processing city - la union, ID number -3593500
# Processing city - vaini, ID number -1273574
# Processing city - jamestown, ID number -2069194
# Processing city - thompson, ID number -6165406
# Processing city - nikolskoye, ID number -546105

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_frame['date'] = pd.to_datetime('today').strftime("%m/%d/%Y")
weather_frame.head()
# Out:
#         lats        lngs    city country       ID temperature humidity  \
# 0  34.099091  126.176157   fukue      JP  1848373      295.15       94
# 1  -6.701704  127.074337   ambon      FR  3037899      291.15       63
# 2  77.129927  166.884959   pevek      RU  2122090     281.049       93
# 3 -68.233555  101.845776  albany      US  5106834      299.54       58
# 4 -54.739801  149.718599  hobart      AU  2163355      288.15       51
#
#   cloudiness wind_speed        date
# 0         75        5.7  09/13/2018
# 1          0        3.1  09/13/2018
# 2         56       2.31  09/13/2018
# 3         75        1.5  09/13/2018
# 4         75        5.7  09/13/2018

# %%
weather_frame = weather_frame.loc[weather_frame['temperature']!= '']
weather_frame.to_csv(output_data_file)
weather_frame.head()
# Out:
#         lats        lngs    city country       ID temperature humidity  \
# 0  34.099091  126.176157   fukue      JP  1848373      295.15       94
# 1  -6.701704  127.074337   ambon      FR  3037899      291.15       63
# 2  77.129927  166.884959   pevek      RU  2122090     281.049       93
# 3 -68.233555  101.845776  albany      US  5106834      299.54       58
# 4 -54.739801  149.718599  hobart      AU  2163355      288.15       51
#
#   cloudiness wind_speed        date
# 0         75        5.7  09/13/2018
# 1          0        3.1  09/13/2018
# 2         56       2.31  09/13/2018
# 3         75        1.5  09/13/2018
# 4         75        5.7  09/13/2018

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# function for setting chart properties

def chart_propoerties (x,y, value):
    fig,ax = plt.subplots()
    ax = plt.scatter(x=x,y=y)

    plt.title(f"Latitude vs. {value} on {weather_frame.date.unique()}" )
    plt.xlabel('Latitudes')
    plt.ylabel(f'{value}')
    plt.grid()
    plt.savefig(f'../output_data/Latitude vs {value}.png')
    plt.show()

# %%
x = weather_frame['lats'] 
y = weather_frame['temperature'].astype(np.float) 

chart_propoerties (x,y, 'Temperature')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
x = weather_frame['lats'] 
y = weather_frame['humidity']
chart_propoerties (x,y, 'Humidity')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
x = weather_frame['lats'] 
y = weather_frame['cloudiness']

chart_propoerties (x,y, 'Cloudiness')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
x = weather_frame['lats'] 
y = weather_frame['wind_speed']
chart_propoerties (x,y, 'Wind Speed')
